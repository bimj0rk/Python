# %%
#%%

import tensorflow as tf
import tf_keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tf_keras import layers
from tf_keras.models import Sequential
from sklearn.metrics import confusion_matrix
from tf_keras.optimizers import Adam
from tf_keras.regularizers import l2

gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
  tf.config.experimental.set_memory_growth(gpu_devices[0], True)
  print('GPU found', gpu_devices[0])
else:
  print('No GPU found')

#define image size
IMG_SIZE = 224

#define batch size
BATCH_SIZE = 32

#training and valdiation directories
TRAINING_DIR = "Train"
  
#training split
train_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = "training",
  validation_split = 0.2,
  seed = 225
)

#validation split, taken directly from the same directory as train
validation_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = 'validation',
  validation_split = 0.2,
  seed = 225
)

CLASS_NAMES = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size = AUTOTUNE)
val_ds = validation_ds.cache().prefetch(buffer_size = AUTOTUNE)

#normalizing the data
norm_layer = layers.Rescaling(1./255)
norm_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
image_batch, labels_batch = next(iter(norm_ds))

#data augmentation to increase robustness
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip('horizontal'),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2) 
])

def augment_images(image, label):
  image = data_augmentation(image)
  return image, label

train_ds = train_ds.map(augment_images)

num_classes = len(CLASS_NAMES)

#training model
model = Sequential([
  layers.Conv2D(64, (3, 3), activation = 'relu', input_shape = (224, 224, 3)),
  layers.BatchNormalization(),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(64, (3, 3), activation = 'relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(128, (3, 3), activation = 'relu', input_shape = (224, 224, 3)),
  layers.BatchNormalization(),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(128, (3, 3), activation = 'relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(256, (3, 3), activation = 'relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(256, (3, 3), activation = 'relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(2, 2),
  layers.Flatten(),
  layers.Dense(512, activation = 'relu', kernel_regularizer = l2(0.01)),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation = 'softmax')
])

model.summary()

model.compile(optimizer = 'adam', 
              loss = tf_keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'])

#no of epochs
epochs = 100


#early stopping
early_stopping = tf_keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                  mode = 'min', 
                                                  verbose = 1, 
                                                  patience = 8, 
                                                  restore_best_weights = True)

#class weights since the dataset is imbalanced
class_weights = {
    0: 0.657,  #bike
    1: 1.165,  #bus
    2: 1.007,  #cng
    3: 0.884,  #easy bike
    4: 1.384,  #hatchback
    5: 1.296,  #mpv
    6: 2.688,  #pickup
    7: 0.694,  #sedan
    8: 1.117,  #suv
    9: 0.769   #truck
}


#fitting of the model
history = model.fit(train_ds, 
                    validation_data = validation_ds, 
                    epochs = epochs,
                    class_weight = class_weights, 
                    callbacks = [early_stopping])

#accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

true_labels = []
predicted_labels = []

for images, labels in val_ds:
  true_labels.extend(labels.numpy())
  pred = model.predict(images)
  predicted_labels.extend(np.argmax(pred, axis = 1))

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

print('Confusion Matrix: ')
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_matrix, annot = True, fmt = 'd', xticklabels = CLASS_NAMES, yticklabels = CLASS_NAMES, cmap = 'Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')


score = model.evaluate(validation_ds, verbose = 0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label = 'Training Loss')
plt.plot(val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 2025-01-19 20:03:12.092434: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737309792.107234  127924 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737309792.111621  127924 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-19 20:03:12.126756: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Found 6480 files belonging to 10 classes.
# Using 5184 files for training.
# I0000 00:00:1737309794.614460  127924 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4729 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# Found 6480 files belonging to 10 classes.
# Using 1296 files for validation.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  batch_normalization (Batch  (None, 222, 222, 64)      256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      36928
#
#  batch_normalization_1 (Bat  (None, 109, 109, 64)      256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 52, 52, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  batch_normalization_4 (Bat  (None, 10, 10, 256)       1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         590080
#
#  batch_normalization_5 (Bat  (None, 3, 3, 256)         1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1285706 (4.90 MB)
# Trainable params: 1283914 (4.90 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________
# Epoch 1/100
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# I0000 00:00:1737309802.155122  128005 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737309803.837264  128005 service.cc:148] XLA service 0x7f84c70b9f30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737309803.837298  128005 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1060 6GB, Compute Capability 6.1
# 2025-01-19 20:03:23.842448: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1737309803.922341  128005 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 131/162 [=======================>......] - ETA: 7s - loss: 5.0963 - accuracy: 0.2541
# 2025-01-19 20:03:58.417279: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 59s 314ms/step - loss: 4.8987 - accuracy: 0.2620 - val_loss: 4.8365 - val_accuracy: 0.2006
# Epoch 2/100
# 131/162 [=======================>......] - ETA: 7s - loss: 3.4172 - accuracy: 0.3504
# 2025-01-19 20:04:52.502477: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 315ms/step - loss: 3.3215 - accuracy: 0.3617 - val_loss: 2.9801 - val_accuracy: 0.3488
# Epoch 3/100
# 131/162 [=======================>......] - ETA: 7s - loss: 2.5760 - accuracy: 0.3989
# 2025-01-19 20:05:45.752782: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 314ms/step - loss: 2.5356 - accuracy: 0.3966 - val_loss: 2.5011 - val_accuracy: 0.3356
# Epoch 4/100
# 131/162 [=======================>......] - ETA: 7s - loss: 2.1704 - accuracy: 0.4215
# 2025-01-19 20:06:38.753880: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 317ms/step - loss: 2.1285 - accuracy: 0.4279 - val_loss: 1.9966 - val_accuracy: 0.4221
# Epoch 5/100
# 131/162 [=======================>......] - ETA: 8s - loss: 1.9036 - accuracy: 0.4540
# 2025-01-19 20:07:35.177015: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 57s 337ms/step - loss: 1.8882 - accuracy: 0.4547 - val_loss: 2.2887 - val_accuracy: 0.3333
# Epoch 6/100
# 131/162 [=======================>......] - ETA: 8s - loss: 1.7694 - accuracy: 0.4816
# 2025-01-19 20:08:30.990609: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 56s 332ms/step - loss: 1.7538 - accuracy: 0.4828 - val_loss: 3.5262 - val_accuracy: 0.2176
# Epoch 7/100
# 131/162 [=======================>......] - ETA: 8s - loss: 1.6831 - accuracy: 0.4857
# 2025-01-19 20:09:25.638982: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 321ms/step - loss: 1.6698 - accuracy: 0.4869 - val_loss: 1.7710 - val_accuracy: 0.4398
# Epoch 8/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.6168 - accuracy: 0.5100
# 2025-01-19 20:10:18.620720: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 316ms/step - loss: 1.6027 - accuracy: 0.5147 - val_loss: 1.8997 - val_accuracy: 0.4437
# Epoch 9/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.5376 - accuracy: 0.5317
# 2025-01-19 20:11:12.374667: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 318ms/step - loss: 1.5394 - accuracy: 0.5324 - val_loss: 1.7056 - val_accuracy: 0.4660
# Epoch 10/100
# 130/162 [=======================>......] - ETA: 8s - loss: 1.4985 - accuracy: 0.5490
# 2025-01-19 20:12:04.995912: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 312ms/step - loss: 1.4907 - accuracy: 0.5517 - val_loss: 1.6955 - val_accuracy: 0.4699
# Epoch 11/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.4451 - accuracy: 0.5637
# 2025-01-19 20:12:58.180050: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 316ms/step - loss: 1.4442 - accuracy: 0.5658 - val_loss: 1.8733 - val_accuracy: 0.4113
# Epoch 12/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.4314 - accuracy: 0.5706
# 2025-01-19 20:13:51.522214: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 315ms/step - loss: 1.4275 - accuracy: 0.5729 - val_loss: 1.6474 - val_accuracy: 0.4761
# Epoch 13/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.3794 - accuracy: 0.5892
# 2025-01-19 20:14:44.648756: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 315ms/step - loss: 1.3736 - accuracy: 0.5876 - val_loss: 1.7841 - val_accuracy: 0.4352
# Epoch 14/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.3372 - accuracy: 0.6047
# 2025-01-19 20:15:38.278451: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 318ms/step - loss: 1.3271 - accuracy: 0.6100 - val_loss: 1.8655 - val_accuracy: 0.4653
# Epoch 15/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.2902 - accuracy: 0.6159
# 2025-01-19 20:16:31.767710: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 318ms/step - loss: 1.2977 - accuracy: 0.6136 - val_loss: 2.5289 - val_accuracy: 0.3287
# Epoch 16/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.2676 - accuracy: 0.6276
# 2025-01-19 20:17:25.424965: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 315ms/step - loss: 1.2731 - accuracy: 0.6240 - val_loss: 1.9610 - val_accuracy: 0.4468
# Epoch 17/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.2842 - accuracy: 0.6360
# 2025-01-19 20:18:18.581817: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 316ms/step - loss: 1.2714 - accuracy: 0.6368 - val_loss: 1.7620 - val_accuracy: 0.4799
# Epoch 18/100
# 131/162 [=======================>......] - ETA: 8s - loss: 1.2734 - accuracy: 0.6312
# 2025-01-19 20:19:12.173979: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 320ms/step - loss: 1.2531 - accuracy: 0.6379 - val_loss: 1.5678 - val_accuracy: 0.5170
# Epoch 19/100
# 131/162 [=======================>......] - ETA: 8s - loss: 1.1982 - accuracy: 0.6555
# 2025-01-19 20:20:06.115509: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 321ms/step - loss: 1.1930 - accuracy: 0.6555 - val_loss: 1.6318 - val_accuracy: 0.5309
# Epoch 20/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.1846 - accuracy: 0.6591
# 2025-01-19 20:20:59.741801: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 316ms/step - loss: 1.1740 - accuracy: 0.6601 - val_loss: 1.4446 - val_accuracy: 0.5887
# Epoch 21/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.1560 - accuracy: 0.6856
# 2025-01-19 20:21:53.000998: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 316ms/step - loss: 1.1381 - accuracy: 0.6869 - val_loss: 1.4631 - val_accuracy: 0.5756
# Epoch 22/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.1355 - accuracy: 0.6832
# 2025-01-19 20:22:45.979174: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 52s 311ms/step - loss: 1.1225 - accuracy: 0.6875 - val_loss: 1.5754 - val_accuracy: 0.5610
# Epoch 23/100
# 131/162 [=======================>......] - ETA: 8s - loss: 1.1140 - accuracy: 0.6925
# 2025-01-19 20:23:39.473055: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 320ms/step - loss: 1.0999 - accuracy: 0.6991 - val_loss: 1.3771 - val_accuracy: 0.6026
# Epoch 24/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.0826 - accuracy: 0.7025
# 2025-01-19 20:24:33.011912: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 319ms/step - loss: 1.0631 - accuracy: 0.7068 - val_loss: 2.2014 - val_accuracy: 0.4336
# Epoch 25/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.0566 - accuracy: 0.7097
# 2025-01-19 20:25:26.710601: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 316ms/step - loss: 1.0507 - accuracy: 0.7093 - val_loss: 1.4037 - val_accuracy: 0.6003
# Epoch 26/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.0748 - accuracy: 0.7145
# 2025-01-19 20:26:19.418440: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 313ms/step - loss: 1.0615 - accuracy: 0.7159 - val_loss: 2.0435 - val_accuracy: 0.4900
# Epoch 27/100
# 131/162 [=======================>......] - ETA: 7s - loss: 1.0146 - accuracy: 0.7254
# 2025-01-19 20:27:12.857593: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 317ms/step - loss: 1.0025 - accuracy: 0.7290 - val_loss: 2.0733 - val_accuracy: 0.4653
# Epoch 28/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.9389 - accuracy: 0.7481
# 2025-01-19 20:28:06.328973: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 319ms/step - loss: 0.9462 - accuracy: 0.7469 - val_loss: 1.3303 - val_accuracy: 0.6142
# Epoch 29/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.9679 - accuracy: 0.7400
# 2025-01-19 20:29:00.053278: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 318ms/step - loss: 0.9611 - accuracy: 0.7378 - val_loss: 1.9111 - val_accuracy: 0.4838
# Epoch 30/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.9789 - accuracy: 0.7431
# 2025-01-19 20:29:53.319825: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 312ms/step - loss: 0.9712 - accuracy: 0.7452 - val_loss: 1.5531 - val_accuracy: 0.5664
# Epoch 31/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.9461 - accuracy: 0.7505
# 2025-01-19 20:30:45.922022: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 314ms/step - loss: 0.9363 - accuracy: 0.7527 - val_loss: 1.5764 - val_accuracy: 0.5741
# Epoch 32/100
# 131/162 [=======================>......] - ETA: 8s - loss: 0.9325 - accuracy: 0.7533
# 2025-01-19 20:31:40.010969: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 55s 324ms/step - loss: 0.9140 - accuracy: 0.7571 - val_loss: 1.5682 - val_accuracy: 0.5741
# Epoch 33/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.9060 - accuracy: 0.7700
# 2025-01-19 20:32:33.507478: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 317ms/step - loss: 0.9061 - accuracy: 0.7693 - val_loss: 1.5658 - val_accuracy: 0.5764
# Epoch 34/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.9158 - accuracy: 0.7684
# 2025-01-19 20:33:27.285109: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 53s 317ms/step - loss: 0.9147 - accuracy: 0.7664 - val_loss: 1.7542 - val_accuracy: 0.5239
# Epoch 35/100
# 131/162 [=======================>......] - ETA: 8s - loss: 0.8670 - accuracy: 0.7834
# 2025-01-19 20:34:21.036876: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 319ms/step - loss: 0.8716 - accuracy: 0.7803 - val_loss: 2.0622 - val_accuracy: 0.4853
# Epoch 36/100
# 131/162 [=======================>......] - ETA: 7s - loss: 0.8863 - accuracy: 0.7781
# 2025-01-19 20:35:14.279682: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 162/162 [==============================] - 54s 319ms/step - loss: 0.8692 - accuracy: 0.7843 - val_loss: 1.4627 - val_accuracy: 0.6011
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 28.
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 122ms/step
# Confusion Matrix:
# 2025-01-19 20:35:43.415578: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation loss: 1.330291509628296
# Validation accuracy: 0.6141975522041321
