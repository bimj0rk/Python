# %%
#%%

import tensorflow as tf
import tf_keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tf_keras import layers
from tf_keras.models import Sequential
from sklearn.metrics import confusion_matrix
from tf_keras.optimizers import Adam
from tf_keras.regularizers import l2

tf.keras.backend.clear_session()

gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
  tf.config.experimental.set_memory_growth(gpu_devices[0], True)
  print('GPU found', gpu_devices[0])
else:
  print('No GPU found')

#define image size
IMG_SIZE = 224

#define batch size
BATCH_SIZE = 32

#training directory
TRAINING_DIR = "Train"
  
#training split
train_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = "training",
  validation_split = 0.25,
  shuffle = True,
  seed = 225
)

#validation split, taken directly from the same directory as train
validation_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = 'validation',
  validation_split = 0.25,
  shuffle = False, #no need to shuffle validation data
  seed = 225
)

CLASS_NAMES = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size = AUTOTUNE)
val_ds = validation_ds.cache().prefetch(buffer_size = AUTOTUNE)

#data augmentation to increase robustness
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip('horizontal'),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2) 
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training = True), y), num_parallel_calls = AUTOTUNE)

num_classes = len(CLASS_NAMES)

#normalizing the data
norm_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
validation_ds = validation_ds.map(lambda x, y: (norm_layer(x), y))

#training model
model = Sequential([
  layers.Conv2D(32, (3, 3),  input_shape = (224, 224, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(64, (3, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(128, (5, 5)), 
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Flatten(),
  layers.Dense(256, activation = 'relu', kernel_regularizer = l2(0.02)),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation = 'softmax')
])

model.compile(optimizer = Adam(learning_rate = 0.0001, weight_decay = 1e-6), 
              loss = tf_keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'])

#no of epochs
epochs = 50


#early stopping
early_stopping = tf_keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                  mode = 'min', 
                                                  verbose = 1, 
                                                  patience = 10, 
                                                  restore_best_weights = True)
                                       

#class weights since the dataset is imbalanced
class_weights = {
    0: 0.657,  #bike
    1: 1.165,  #bus
    2: 1.006,  #cng
    3: 0.885,  #easy bike
    4: 1.385,  #hatchback
    5: 1.296,  #mpv
    6: 2.689,  #pickup
    7: 0.695,  #sedan
    8: 1.117,  #suv
    9: 0.770   #truck
}

#fitting of the model
history = model.fit(train_ds, 
                    validation_data = validation_ds, 
                    epochs = epochs,
                    class_weight = class_weights,
                    callbacks = [early_stopping])

#accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

true_labels = []
predicted_labels = []

for images, labels in val_ds:
  true_labels.extend(labels.numpy())
  pred = model.predict(images)
  predicted_labels.extend(np.argmax(pred, axis = 1))

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

print('Confusion Matrix: ')
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_matrix, annot = True, fmt = 'd', xticklabels = CLASS_NAMES, yticklabels = CLASS_NAMES, cmap = 'Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

score = model.evaluate(validation_ds, verbose = 0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label = 'Training Loss')
plt.plot(val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 2025-01-20 12:35:15.631460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737369315.647016  382663 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737369315.651518  382663 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-20 12:35:15.666547: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Found 6480 files belonging to 10 classes.
# Using 4860 files for training.
# I0000 00:00:1737369318.481058  382663 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4817 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# Found 6480 files belonging to 10 classes.
# Using 1620 files for validation.
# Epoch 1/50
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# I0000 00:00:1737369323.366600  382716 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737369324.930259  382713 service.cc:148] XLA service 0x760ca062fb30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737369324.930288  382713 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1060 6GB, Compute Capability 6.1
# 2025-01-20 12:35:24.936366: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1737369325.054847  382713 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 131/152 [========================>.....] - ETA: 5s - loss: 5.2144 - accuracy: 0.1589
# 2025-01-20 12:36:02.134270: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 57s 329ms/step - loss: 4.8644 - accuracy: 0.1673 - val_loss: 2.2458 - val_accuracy: 0.4815
# Epoch 2/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.3863 - accuracy: 0.2397
# 2025-01-20 12:36:57.285819: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 334ms/step - loss: 2.3733 - accuracy: 0.2426 - val_loss: 2.0082 - val_accuracy: 0.3469
# Epoch 3/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.2303 - accuracy: 0.2739
# 2025-01-20 12:37:50.312742: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 349ms/step - loss: 2.2338 - accuracy: 0.2706 - val_loss: 1.7937 - val_accuracy: 0.5167
# Epoch 4/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.1877 - accuracy: 0.2982
# 2025-01-20 12:38:45.242876: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 346ms/step - loss: 2.1853 - accuracy: 0.3006 - val_loss: 1.8219 - val_accuracy: 0.4364
# Epoch 5/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.1328 - accuracy: 0.3170
# 2025-01-20 12:39:40.542094: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 331ms/step - loss: 2.1221 - accuracy: 0.3195 - val_loss: 1.6673 - val_accuracy: 0.5463
# Epoch 6/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0817 - accuracy: 0.3368
# 2025-01-20 12:40:32.530822: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 52s 329ms/step - loss: 2.0882 - accuracy: 0.3340 - val_loss: 1.7826 - val_accuracy: 0.4290
# Epoch 7/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0734 - accuracy: 0.3464
# 2025-01-20 12:41:25.500824: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 331ms/step - loss: 2.0648 - accuracy: 0.3510 - val_loss: 1.7269 - val_accuracy: 0.4858
# Epoch 8/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0394 - accuracy: 0.3597
# 2025-01-20 12:42:17.213316: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 51s 322ms/step - loss: 2.0361 - accuracy: 0.3626 - val_loss: 1.6739 - val_accuracy: 0.5068
# Epoch 9/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.0204 - accuracy: 0.3833
# 2025-01-20 12:43:07.911005: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 51s 318ms/step - loss: 2.0140 - accuracy: 0.3854 - val_loss: 1.5820 - val_accuracy: 0.5549
# Epoch 10/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9895 - accuracy: 0.3831
# 2025-01-20 12:43:56.272691: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 47s 299ms/step - loss: 2.0015 - accuracy: 0.3790 - val_loss: 1.5870 - val_accuracy: 0.5556
# Epoch 11/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9853 - accuracy: 0.3872
# 2025-01-20 12:44:44.120078: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 48s 302ms/step - loss: 1.9849 - accuracy: 0.3879 - val_loss: 1.6780 - val_accuracy: 0.4870
# Epoch 12/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9680 - accuracy: 0.4058
# 2025-01-20 12:45:32.236118: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 49s 305ms/step - loss: 1.9788 - accuracy: 0.4035 - val_loss: 1.6589 - val_accuracy: 0.5296
# Epoch 13/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9543 - accuracy: 0.4020
# 2025-01-20 12:46:19.640390: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 47s 293ms/step - loss: 1.9589 - accuracy: 0.4035 - val_loss: 1.5977 - val_accuracy: 0.5562
# Epoch 14/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9403 - accuracy: 0.4110
# 2025-01-20 12:47:07.968880: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 49s 306ms/step - loss: 1.9459 - accuracy: 0.4101 - val_loss: 1.6226 - val_accuracy: 0.5500
# Epoch 15/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9197 - accuracy: 0.4234
# 2025-01-20 12:47:56.802851: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 49s 309ms/step - loss: 1.9261 - accuracy: 0.4210 - val_loss: 1.7796 - val_accuracy: 0.4475
# Epoch 16/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9196 - accuracy: 0.4215
# 2025-01-20 12:48:45.284581: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 48s 300ms/step - loss: 1.9227 - accuracy: 0.4216 - val_loss: 1.7483 - val_accuracy: 0.4451
# Epoch 17/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9188 - accuracy: 0.4234
# 2025-01-20 12:49:33.333398: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 48s 304ms/step - loss: 1.9265 - accuracy: 0.4222 - val_loss: 1.6937 - val_accuracy: 0.5340
# Epoch 18/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.9061 - accuracy: 0.4184
# 2025-01-20 12:50:21.384021: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 48s 304ms/step - loss: 1.9056 - accuracy: 0.4185 - val_loss: 1.6335 - val_accuracy: 0.5290
# Epoch 19/50
# 131/152 [========================>.....] - ETA: 5s - loss: 1.8980 - accuracy: 0.4263
# 2025-01-20 12:51:09.899137: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 48s 302ms/step - loss: 1.8979 - accuracy: 0.4280 - val_loss: 1.9623 - val_accuracy: 0.3938
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 53ms/step
# Confusion Matrix:
# 2025-01-20 12:51:28.513138: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation loss: 1.5819525718688965
# Validation accuracy: 0.5549382567405701

# %%
#%%

import tensorflow as tf
import tf_keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tf_keras import layers
from tf_keras.models import Sequential
from sklearn.metrics import confusion_matrix
from tf_keras.optimizers import Adam
from tf_keras.regularizers import l2

tf.keras.backend.clear_session()

gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
  tf.config.experimental.set_memory_growth(gpu_devices[0], True)
  print('GPU found', gpu_devices[0])
else:
  print('No GPU found')

#define image size
IMG_SIZE = 224

#define batch size
BATCH_SIZE = 32

#training directory
TRAINING_DIR = "Train"
  
#training split
train_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = "training",
  validation_split = 0.25,
  seed = 225
)

#validation split, taken directly from the same directory as train
validation_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = 'validation',
  validation_split = 0.25,
  shuffle = False, #no need to shuffle validation data
  seed = 225
)

CLASS_NAMES = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size = AUTOTUNE)
val_ds = validation_ds.cache().prefetch(buffer_size = AUTOTUNE)

#data augmentation to increase robustness
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip('horizontal'),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2) 
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training = True), y), num_parallel_calls = AUTOTUNE)

num_classes = len(CLASS_NAMES)

#normalizing the data
norm_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
validation_ds = validation_ds.map(lambda x, y: (norm_layer(x), y))

#training model
model = Sequential([
  layers.Conv2D(32, (3, 3),  input_shape = (224, 224, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(64, (3, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(128, (5, 5)), 
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Flatten(),
  layers.Dense(256, activation = 'relu', kernel_regularizer = l2(0.02)),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation = 'softmax')
])

model.compile(optimizer = Adam(learning_rate = 0.0001, weight_decay = 1e-6), 
              loss = tf_keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'])

#no of epochs
epochs = 10


#early stopping
early_stopping = tf_keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                  mode = 'min', 
                                                  verbose = 1, 
                                                  patience = 10, 
                                                  restore_best_weights = True)
                                       

#class weights since the dataset is imbalanced
class_weights = {
    0: 0.657,  #bike
    1: 1.165,  #bus
    2: 1.006,  #cng
    3: 0.885,  #easy bike
    4: 1.385,  #hatchback
    5: 1.296,  #mpv
    6: 2.689,  #pickup
    7: 0.695,  #sedan
    8: 1.117,  #suv
    9: 0.770   #truck
}

#fitting of the model
history = model.fit(train_ds, 
                    validation_data = validation_ds, 
                    epochs = epochs,
                    class_weight = class_weights,
                    callbacks = [early_stopping])

#accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

true_labels = []
predicted_labels = []

for images, labels in val_ds:
  true_labels.extend(labels.numpy())
  pred = model.predict(images)
  predicted_labels.extend(np.argmax(pred, axis = 1))

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

print('Confusion Matrix: ')
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_matrix, annot = True, fmt = 'd', xticklabels = CLASS_NAMES, yticklabels = CLASS_NAMES, cmap = 'Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

score = model.evaluate(validation_ds, verbose = 0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label = 'Training Loss')
plt.plot(val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# GPU found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Found 6480 files belonging to 10 classes.
# Using 4860 files for training.
# Found 6480 files belonging to 10 classes.
# Using 1620 files for validation.
# Epoch 1/10
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 131/152 [========================>.....] - ETA: 5s - loss: 5.1904 - accuracy: 0.1450
# 2025-01-20 12:53:21.524997: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 344ms/step - loss: 4.8371 - accuracy: 0.1531 - val_loss: 2.0856 - val_accuracy: 0.5593
# Epoch 2/10
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3486 - accuracy: 0.2653
# 2025-01-20 12:54:15.157917: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 51s 319ms/step - loss: 2.3364 - accuracy: 0.2667 - val_loss: 1.9713 - val_accuracy: 0.4111
# Epoch 3/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.1910 - accuracy: 0.3065
# 2025-01-20 12:55:08.822338: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 335ms/step - loss: 2.1857 - accuracy: 0.3062 - val_loss: 1.9805 - val_accuracy: 0.3340
# Epoch 4/10
# 131/152 [========================>.....] - ETA: 5s - loss: 2.1511 - accuracy: 0.3282
# 2025-01-20 12:56:00.310278: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 51s 320ms/step - loss: 2.1484 - accuracy: 0.3300 - val_loss: 1.8291 - val_accuracy: 0.4698
# Epoch 5/10
# 131/152 [========================>.....] - ETA: 5s - loss: 2.1099 - accuracy: 0.3497
# 2025-01-20 12:56:50.705546: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 336ms/step - loss: 2.1010 - accuracy: 0.3549 - val_loss: 1.6612 - val_accuracy: 0.5722
# Epoch 6/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0790 - accuracy: 0.3569
# 2025-01-20 12:58:15.846067: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 348ms/step - loss: 2.0807 - accuracy: 0.3570 - val_loss: 1.8073 - val_accuracy: 0.4599
# Epoch 7/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0484 - accuracy: 0.3738
# 2025-01-20 12:59:11.300040: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 346ms/step - loss: 2.0423 - accuracy: 0.3757 - val_loss: 1.6883 - val_accuracy: 0.5253
# Epoch 8/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0367 - accuracy: 0.3893
# 2025-01-20 13:00:05.189445: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 337ms/step - loss: 2.0285 - accuracy: 0.3916 - val_loss: 1.7225 - val_accuracy: 0.4932
# Epoch 9/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0325 - accuracy: 0.3869
# 2025-01-20 13:01:26.749209: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 331ms/step - loss: 2.0247 - accuracy: 0.3889 - val_loss: 1.9392 - val_accuracy: 0.4093
# Epoch 10/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0115 - accuracy: 0.4008
# 2025-01-20 13:02:18.746098: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 53s 334ms/step - loss: 2.0135 - accuracy: 0.3973 - val_loss: 1.8262 - val_accuracy: 0.4512
# Restoring model weights from the end of the best epoch: 5.
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 72ms/step
# Confusion Matrix:
# 2025-01-20 13:02:40.412803: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation loss: 1.6612290143966675
# Validation accuracy: 0.5722222328186035

# %%
#%%

import tensorflow as tf
import tf_keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tf_keras import layers
from tf_keras.models import Sequential
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
import numpy as np
from tf_keras.optimizers import Adam
from tf_keras.regularizers import l2

tf.keras.backend.clear_session()

gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
  tf.config.experimental.set_memory_growth(gpu_devices[0], True)
  print('GPU found', gpu_devices[0])
else:
  print('No GPU found')

#define image size
IMG_SIZE = 224

#define batch size
BATCH_SIZE = 32

#training directory
TRAINING_DIR = "Train"
  
#training split
train_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = "training",
  validation_split = 0.25,
  seed = 225
)

#validation split, taken directly from the same directory as train
validation_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = 'validation',
  validation_split = 0.25,
  seed = 225
)

CLASS_NAMES = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size = AUTOTUNE)
val_ds = validation_ds.cache().prefetch(buffer_size = AUTOTUNE)

#data augmentation to increase robustness
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip('horizontal'),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2) 
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training = True), y), num_parallel_calls = AUTOTUNE)

num_classes = len(CLASS_NAMES)

#normalizing the data
norm_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
validation_ds = validation_ds.map(lambda x, y: (norm_layer(x), y))

#training model
model = Sequential([
  layers.Conv2D(32, (3, 3),  input_shape = (224, 224, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.2),  
  layers.Conv2D(64, (3, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.2),
  layers.Conv2D(128, (5, 5)), 
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(256, activation = 'relu', kernel_regularizer = l2(0.02)),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation = 'softmax')
])

model.compile(optimizer = Adam(learning_rate = 0.0001, weight_decay = 1e-6), 
              loss = tf_keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'])

#no of epochs
epochs = 10


#early stopping
early_stopping = tf_keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                  mode = 'min', 
                                                  verbose = 1, 
                                                  patience = 10, 
                                                  restore_best_weights = True)
                                       

#class weights since the dataset is imbalanced

class_weights = compute_class_weight(
    class_weight = 'balanced',
    classes = np.unique(CLASS_NAMES),  
    y = CLASS_NAMES
)

class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)

#fitting of the model
history = model.fit(train_ds, 
                    validation_data = validation_ds, 
                    epochs = epochs,
                    class_weight = class_weights,
                    callbacks = [early_stopping])

#accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

true_labels = []
predicted_labels = []

for images, labels in val_ds:
  true_labels.extend(labels.numpy())
  pred = model.predict(images)
  predicted_labels.extend(np.argmax(pred, axis = 1))

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

print('Confusion Matrix: ')
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_matrix, annot = True, fmt = 'd', xticklabels = CLASS_NAMES, yticklabels = CLASS_NAMES, cmap = 'Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

score = model.evaluate(validation_ds, verbose = 0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label = 'Training Loss')
plt.plot(val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# GPU found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Found 6480 files belonging to 10 classes.
# Using 4860 files for training.
# Found 6480 files belonging to 10 classes.
# Using 1620 files for validation.
# Class Weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0), 5: np.float64(1.0), 6: np.float64(1.0), 7: np.float64(1.0), 8: np.float64(1.0), 9: np.float64(1.0)}
# Epoch 1/10
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# E0000 00:00:1737370977.724187  382663 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 126
#     123 print("Class Weights:", class_weights)
#     125 #fitting of the model
# --> 126 history = model.fit(train_ds,
#     127                     validation_data = validation_ds,
#     128                     epochs = epochs,
#     129                     class_weight = class_weights,
#     130                     callbacks = [early_stopping])
#     132 #accuracy and loss values
#     133 accuracy = history.history['accuracy']
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/engine/training.py:1804, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796 with tf.profiler.experimental.Trace(
#    1797     "train",
#    1798     epoch_num=epoch,
#    (...)
#    1801     _r=1,
#    1802 ):
#    1803     callbacks.on_train_batch_begin(step)
# -> 1804     tmp_logs = self.train_function(iterator)
#    1805     if data_handler.should_sync:
#    1806         context.async_wait()
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:906, in Function._call(self, *args, **kwds)
#     902     pass  # Fall through to cond-based initialization.
#     903   else:
#     904     # Lifting succeeded, so variables are initialized and we can run the
#     905     # no_variable_creation function.
# --> 906     return tracing_compilation.call_function(
#     907         args, kwds, self._no_variable_creation_config
#     908     )
#     909 else:
#     910   bound_args = self._concrete_variable_creation_fn.function_type.bind(
#     911       *args, **kwds
#     912   )
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#%%

import tensorflow as tf
import tf_keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tf_keras import layers
from tf_keras.models import Sequential
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report
import numpy as np
from tf_keras.optimizers import Adam
from tf_keras.regularizers import l2

tf.keras.backend.clear_session()

gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
  tf.config.experimental.set_memory_growth(gpu_devices[0], True)
  print('GPU found', gpu_devices[0])
else:
  print('No GPU found')

#define image size
IMG_SIZE = 224

#define batch size
BATCH_SIZE = 32

#training directory
TRAINING_DIR = "Train"
  
#training split
train_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = "training",
  validation_split = 0.25,
  seed = 225
)

#validation split, taken directly from the same directory as train
validation_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = 'validation',
  validation_split = 0.25,
  seed = 225
)

CLASS_NAMES = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size = AUTOTUNE)
val_ds = validation_ds.cache().prefetch(buffer_size = AUTOTUNE)

#data augmentation to increase robustness
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip('horizontal'),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2) 
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training = True), y), num_parallel_calls = AUTOTUNE)

num_classes = len(CLASS_NAMES)

#normalizing the data
norm_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
validation_ds = validation_ds.map(lambda x, y: (norm_layer(x), y))

#training model
model = Sequential([
  layers.Conv2D(32, (3, 3),  input_shape = (224, 224, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.2),  
  layers.Conv2D(64, (3, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.2),
  layers.Conv2D(128, (5, 5)), 
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(256, activation = 'relu', kernel_regularizer = l2(0.02)),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation = 'softmax')
])

model.compile(optimizer = Adam(learning_rate = 0.0001, weight_decay = 1e-6), 
              loss = tf_keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'])

#no of epochs
epochs = 10


#early stopping
early_stopping = tf_keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                  mode = 'min', 
                                                  verbose = 1, 
                                                  patience = 10, 
                                                  restore_best_weights = True)
                                       

#class weights since the dataset is imbalanced

class_weights = compute_class_weight(
    class_weight = 'balanced',
    classes = np.unique(CLASS_NAMES),  
    y = CLASS_NAMES
)

class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)

#fitting of the model
history = model.fit(train_ds, 
                    validation_data = validation_ds, 
                    epochs = epochs,
                    class_weight = class_weights,
                    callbacks = [early_stopping])

#accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

true_labels = []
predicted_labels = []

for images, labels in val_ds:
  true_labels.extend(labels.numpy())
  pred = model.predict(images)
  predicted_labels.extend(np.argmax(pred, axis = 1))

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

print('Confusion Matrix: ')
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_matrix, annot = True, fmt = 'd', xticklabels = CLASS_NAMES, yticklabels = CLASS_NAMES, cmap = 'Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

score = model.evaluate(validation_ds, verbose = 0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label = 'Training Loss')
plt.plot(val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

print(classification_report(true_labels, predicted_labels, target_names=CLASS_NAMES))
# Out:
# GPU found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Found 6480 files belonging to 10 classes.
# Using 4860 files for training.
# Found 6480 files belonging to 10 classes.
# Using 1620 files for validation.
# Class Weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0), 4: np.float64(1.0), 5: np.float64(1.0), 6: np.float64(1.0), 7: np.float64(1.0), 8: np.float64(1.0), 9: np.float64(1.0)}
# Epoch 1/10
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/tf_keras/src/backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 131/152 [========================>.....] - ETA: 6s - loss: 6.5222 - accuracy: 0.1531
# 2025-01-20 13:03:47.616559: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 60s 367ms/step - loss: 6.1012 - accuracy: 0.1556 - val_loss: 3.3057 - val_accuracy: 0.2160
# Epoch 2/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.7538 - accuracy: 0.2123
# 2025-01-20 13:05:10.274948: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 61s 384ms/step - loss: 2.7086 - accuracy: 0.2175 - val_loss: 2.3982 - val_accuracy: 0.2883
# Epoch 3/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.2670 - accuracy: 0.2648
# 2025-01-20 13:06:09.142901: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 58s 365ms/step - loss: 2.2505 - accuracy: 0.2708 - val_loss: 2.1290 - val_accuracy: 0.3315
# Epoch 4/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.1173 - accuracy: 0.3247
# 2025-01-20 13:07:07.377519: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 58s 368ms/step - loss: 2.1134 - accuracy: 0.3257 - val_loss: 2.0221 - val_accuracy: 0.3765
# Epoch 5/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0681 - accuracy: 0.3333
# 2025-01-20 13:08:06.327572: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 66s 423ms/step - loss: 2.0653 - accuracy: 0.3362 - val_loss: 1.9880 - val_accuracy: 0.3988
# Epoch 6/10
# 131/152 [========================>.....] - ETA: 6s - loss: 2.0171 - accuracy: 0.3709
# 2025-01-20 13:09:12.043496: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 58s 370ms/step - loss: 2.0163 - accuracy: 0.3665 - val_loss: 1.9414 - val_accuracy: 0.4142
# Epoch 7/10
# 131/152 [========================>.....] - ETA: 6s - loss: 1.9908 - accuracy: 0.3683
# 2025-01-20 13:10:10.271959: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 58s 367ms/step - loss: 1.9877 - accuracy: 0.3708 - val_loss: 1.8990 - val_accuracy: 0.4160
# Epoch 8/10
# 131/152 [========================>.....] - ETA: 6s - loss: 1.9630 - accuracy: 0.3845
# 2025-01-20 13:11:08.481737: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 58s 368ms/step - loss: 1.9586 - accuracy: 0.3866 - val_loss: 1.8731 - val_accuracy: 0.4265
# Epoch 9/10
# 131/152 [========================>.....] - ETA: 6s - loss: 1.9662 - accuracy: 0.3948
# 2025-01-20 13:12:08.669012: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 60s 379ms/step - loss: 1.9630 - accuracy: 0.3922 - val_loss: 1.8548 - val_accuracy: 0.4358
# Epoch 10/10
# 131/152 [========================>.....] - ETA: 6s - loss: 1.9392 - accuracy: 0.4060
# 2025-01-20 13:13:06.733344: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 58s 370ms/step - loss: 1.9435 - accuracy: 0.4043 - val_loss: 1.8360 - val_accuracy: 0.4525
# Restoring model weights from the end of the best epoch: 10.
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 57ms/step
# Confusion Matrix:
# Validation loss: 1.8360352516174316
# Validation accuracy: 0.452469140291214
#               precision    recall  f1-score   support
#
#         Bike       0.39      0.65      0.49       258
#          Bus       0.24      0.42      0.31       132
#          CNG       0.78      0.60      0.68       151
#    Easy_Bike       0.41      0.43      0.42       181
#    Hatchback       0.31      0.31      0.31       116
#          MPV       0.35      0.19      0.25       115
#       Pickup       0.00      0.00      0.00        71
#          SUV       0.67      0.01      0.03       149
#        Sedan       0.40      0.51      0.45       239
#        Truck       0.62      0.51      0.56       208
#
#     accuracy                           0.42      1620
#    macro avg       0.42      0.36      0.35      1620
# weighted avg       0.45      0.42      0.39      1620
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adiicmp/GitHub Repos/Python/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#%%

import tensorflow as tf
import tf_keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tf_keras import layers
from tf_keras.models import Sequential
from sklearn.metrics import confusion_matrix
from tf_keras.optimizers import Adam
from tf_keras.regularizers import l2

tf.keras.backend.clear_session()

gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
  tf.config.experimental.set_memory_growth(gpu_devices[0], True)
  print('GPU found', gpu_devices[0])
else:
  print('No GPU found')

#define image size
IMG_SIZE = 224

#define batch size
BATCH_SIZE = 32

#training directory
TRAINING_DIR = "Train"
  
#training split
train_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = "training",
  validation_split = 0.25,
  seed = 225
)

#validation split, taken directly from the same directory as train
validation_ds = tf_keras.utils.image_dataset_from_directory(
  TRAINING_DIR,
  labels = "inferred",
  image_size = (IMG_SIZE, IMG_SIZE),
  batch_size = BATCH_SIZE,
  subset = 'validation',
  validation_split = 0.25,
  seed = 225
)

CLASS_NAMES = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size = AUTOTUNE)
val_ds = validation_ds.cache().prefetch(buffer_size = AUTOTUNE)

#data augmentation to increase robustness
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip('horizontal'),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.2) 
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training = True), y), num_parallel_calls = AUTOTUNE)

num_classes = len(CLASS_NAMES)

#normalizing the data
norm_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (norm_layer(x), y))
validation_ds = validation_ds.map(lambda x, y: (norm_layer(x), y))

#training model
model = Sequential([
  layers.Conv2D(32, (3, 3),  input_shape = (224, 224, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(64, (3, 3)),
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Conv2D(128, (5, 5)), 
  layers.Activation('relu'),
  layers.MaxPooling2D(2, 2),
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(256, activation = 'relu', kernel_regularizer = l2(0.02)),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation = 'softmax'),
  layers.Dropout(0.5),
])

model.compile(optimizer = 'adam', 
              loss = tf_keras.losses.SparseCategoricalCrossentropy(from_logits = True), 
              metrics = ['accuracy'])

#no of epochs
epochs = 50


#early stopping
early_stopping = tf_keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                  mode = 'min', 
                                                  verbose = 1, 
                                                  patience = 8, 
                                                  restore_best_weights = True)
                                       

#class weights since the dataset is imbalanced
class_weights = {
    0: 0.657,  #bike
    1: 1.165,  #bus
    2: 1.006,  #cng
    3: 0.885,  #easy bike
    4: 1.385,  #hatchback
    5: 1.296,  #mpv
    6: 2.689,  #pickup
    7: 0.695,  #sedan
    8: 1.117,  #suv
    9: 0.770   #truck
}

#fitting of the model
history = model.fit(train_ds, 
                    validation_data = validation_ds, 
                    epochs = epochs,
                    class_weight = class_weights,
                    callbacks = [early_stopping])

#accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

true_labels = []
predicted_labels = []

for images, labels in val_ds:
  true_labels.extend(labels.numpy())
  pred = model.predict(images)
  predicted_labels.extend(np.argmax(pred, axis = 1))

confusion_matrix = confusion_matrix(true_labels, predicted_labels)

print('Confusion Matrix: ')
plt.figure(figsize=(8, 8))
sns.heatmap(confusion_matrix, annot = True, fmt = 'd', xticklabels = CLASS_NAMES, yticklabels = CLASS_NAMES, cmap = 'Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

score = model.evaluate(validation_ds, verbose = 0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])

plt.figure(figsize = (8, 8))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label = 'Training Accuracy')
plt.plot(val_accuracy, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label = 'Training Loss')
plt.plot(val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# GPU found PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Found 6480 files belonging to 10 classes.
# Using 4860 files for training.
# Found 6480 files belonging to 10 classes.
# Using 1620 files for validation.
# Epoch 1/50
# E0000 00:00:1737371759.763804  382663 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 131/152 [========================>.....] - ETA: 5s - loss: 2.7147 - accuracy: 0.1147
# 2025-01-20 13:16:37.153766: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 337ms/step - loss: 2.6656 - accuracy: 0.1195 - val_loss: 2.3333 - val_accuracy: 0.1475
# Epoch 2/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3734 - accuracy: 0.1291
# 2025-01-20 13:17:30.214955: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 52s 330ms/step - loss: 2.3759 - accuracy: 0.1311 - val_loss: 2.3297 - val_accuracy: 0.1475
# Epoch 3/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3838 - accuracy: 0.1147
# 2025-01-20 13:18:24.497486: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 348ms/step - loss: 2.3846 - accuracy: 0.1179 - val_loss: 2.3385 - val_accuracy: 0.1475
# Epoch 4/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3745 - accuracy: 0.1310
# 2025-01-20 13:19:19.252007: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 351ms/step - loss: 2.3757 - accuracy: 0.1302 - val_loss: 2.3217 - val_accuracy: 0.1475
# Epoch 5/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3896 - accuracy: 0.1357
# 2025-01-20 13:20:15.048060: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 354ms/step - loss: 2.3786 - accuracy: 0.1393 - val_loss: 2.3100 - val_accuracy: 0.2142
# Epoch 6/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.4049 - accuracy: 0.1486
# 2025-01-20 13:21:10.408819: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 349ms/step - loss: 2.3967 - accuracy: 0.1508 - val_loss: 2.3163 - val_accuracy: 0.2179
# Epoch 7/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3935 - accuracy: 0.1603
# 2025-01-20 13:22:06.391860: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 352ms/step - loss: 2.3847 - accuracy: 0.1613 - val_loss: 2.2984 - val_accuracy: 0.2130
# Epoch 8/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3766 - accuracy: 0.1641
# 2025-01-20 13:23:02.180952: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 356ms/step - loss: 2.3706 - accuracy: 0.1667 - val_loss: 2.3132 - val_accuracy: 0.2204
# Epoch 9/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.3782 - accuracy: 0.1617
# 2025-01-20 13:23:58.384100: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 355ms/step - loss: 2.3700 - accuracy: 0.1675 - val_loss: 2.3156 - val_accuracy: 0.2309
# Epoch 10/50
# 131/152 [========================>.....] - ETA: 6s - loss: 2.4204 - accuracy: 0.1591
# 2025-01-20 13:24:55.884747: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 57s 363ms/step - loss: 2.4161 - accuracy: 0.1621 - val_loss: 2.3334 - val_accuracy: 0.2574
# Epoch 11/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.4325 - accuracy: 0.1682
# 2025-01-20 13:25:51.818989: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 355ms/step - loss: 2.4334 - accuracy: 0.1693 - val_loss: 2.4193 - val_accuracy: 0.2370
# Epoch 12/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.4646 - accuracy: 0.1710
# 2025-01-20 13:26:48.525505: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 56s 355ms/step - loss: 2.4514 - accuracy: 0.1735 - val_loss: 2.3543 - val_accuracy: 0.2290
# Epoch 13/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.4319 - accuracy: 0.1763
# 2025-01-20 13:27:43.379588: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 54s 345ms/step - loss: 2.4295 - accuracy: 0.1784 - val_loss: 2.3334 - val_accuracy: 0.2963
# Epoch 14/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.4592 - accuracy: 0.1877
# 2025-01-20 13:28:38.289015: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 55s 347ms/step - loss: 2.4548 - accuracy: 0.1883 - val_loss: 2.3815 - val_accuracy: 0.2784
# Epoch 15/50
# 131/152 [========================>.....] - ETA: 5s - loss: 2.5092 - accuracy: 0.1832
# 2025-01-20 13:29:32.775000: W tensorflow/core/lib/png/png_io.cc:89] PNG warning: iCCP: known incorrect sRGB profile
# 152/152 [==============================] - 54s 344ms/step - loss: 2.4946 - accuracy: 0.1842 - val_loss: 2.3631 - val_accuracy: 0.2667
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 61ms/step
# Confusion Matrix:
# 2025-01-20 13:30:03.574091: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Validation loss: 2.2983808517456055
# Validation accuracy: 0.21296297013759613
